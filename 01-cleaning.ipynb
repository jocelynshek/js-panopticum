# %%
#creates more_info and headline, main_headline, print_headline
import pandas as pd
import ast
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

full_year = pd.read_csv("../../input-data/temp-data.json")

# Make a copy of the data
more_info = full_year[["_id", "headline", "abstract", "lead_paragraph", "pub_date", "section_name", "subsection_name", "keywords"]].copy()

def extract_headlines(headline_entry):
    # If it's not a dict, try to convert it
    if not isinstance(headline_entry, dict):
        try:
            headline_entry = ast.literal_eval(headline_entry)
        except Exception as e:
            # if conversion fails, use the whole string as both values
            return pd.Series({'main_headline': str(headline_entry), 'print_headline': str(headline_entry)})
    
    main = headline_entry.get('main', '')
    print_head = headline_entry.get('print_headline', '')
    # Use main if print_head is empty or identical to main
    if not print_head or print_head.strip() == '' or print_head == main:
        print_head = main
    return pd.Series({'main_headline': main, 'print_headline': print_head})

# Create the new columns by applying the function
more_info[['main_headline', 'print_headline']] = more_info['headline'].apply(extract_headlines)

# Optional: view the results
more_info.head()

more_info.to_feather("../../data/more_info.feather")

# %%
import ast, json
import pandas as pd

# 1) Define your keyword‐extraction helper
def extract_keyword_values(keyword_entry):
    if isinstance(keyword_entry, list):
        return [d['value'] for d in keyword_entry if isinstance(d, dict) and 'value' in d]
    elif isinstance(keyword_entry, str):
        try:
            data = json.loads(keyword_entry)
        except Exception:
            try:
                data = ast.literal_eval(keyword_entry)
            except Exception:
                return []
        return [d['value'] for d in data if isinstance(d, dict) and 'value' in d]
    else:
        return []

# 2) Define your political‐filter function
def is_political(keywords_entry):
    political_keywords = {
        "Israel-Gaza War (2023- )", "United States International Relations", "Israel",
        "International Relations", "Gaza Strip", "Russian Invasion of Ukraine (2022)",
        "Russia", "Global Warming", "Palestinians", "Hamas", "China", "Ukraine",
        "United States Economy", "Black People", "Blacks", "Immigration and Emigration",
        "Terrorism", "Illegal Immigration", "Prices (Fares, Fees and Rates)",
        "International Trade and World Market", "Discrimination", "Hezbollah", "Abortion",
        "Race and Ethnicity", "Greenhouse Gas Emissions", "Banking and Financial Institutions",
        "Economic Conditions and Trends", "Protectionism (Trade)", "Factories and Manufacturing"
    }
    kws = extract_keyword_values(keywords_entry)
    # case‐insensitive match
    return any(any(pk.lower() in k.lower() for k in kws) for pk in political_keywords)

# 3) Apply it to create a new DataFrame
more_info_political = more_info[ more_info['keywords'].apply(is_political) ].copy()

# 4) (Optional) Recompute any combined fields on the filtered set
more_info_political['combined_text'] = (
    more_info_political['main_headline'].fillna('') + ' ' +
    more_info_political['abstract'].fillna('') + ' ' +
    more_info_political['lead_paragraph'].fillna('')
)

# 5) Persist for downstream work
more_info_political.to_feather("../../data/more_info_political.feather")

# %%
import ast
import json
from collections import Counter
from textblob import TextBlob

# Function to robustly extract keyword values
def extract_keyword_values(keyword_entry):
    if isinstance(keyword_entry, list):
        return [d['value'] for d in keyword_entry if isinstance(d, dict) and 'value' in d]
    elif isinstance(keyword_entry, str):
        try:
            data = json.loads(keyword_entry)
        except Exception:
            try:
                data = ast.literal_eval(keyword_entry)
            except Exception as e:
                print("Error parsing keywords:", e)
                return []
        return [d['value'] for d in data if isinstance(d, dict) and 'value' in d]
    else:
        return []

# Collect all keywords from the dataset
all_keywords = []
for idx, row in more_info.iterrows():
    kws = extract_keyword_values(row['keywords'])
    all_keywords.extend(kws)

# Count the frequency of each keyword
keyword_counts = Counter(all_keywords)

# Filter keywords with more than 5 mentions
filtered_keywords = [kw for kw, count in keyword_counts.items() if count > 5]

# Compute sentiment polarity for each filtered keyword using TextBlob
filtered_keyword_sentiments = {}
for keyword in filtered_keywords:
    polarity = TextBlob(keyword).sentiment.polarity
    filtered_keyword_sentiments[keyword] = polarity

# Sort keywords by the absolute value of polarity (most polarizing first)
sorted_keywords = sorted(filtered_keyword_sentiments.items(), key=lambda x: abs(x[1]), reverse=True)

# Get the top 15 most polarizing keywords
top_15 = sorted_keywords[:15]

print("Top 15 Most Polarizing Keywords (with more than 5 mentions):")
for kw, sentiment in top_15:
    print(f"{kw} (mentions: {keyword_counts[kw]}): {sentiment}")
# Out:
# Top 15 Most Polarizing Keywords (with more than 5 mentions):
# Drilling and Boring (mentions: 15): -1.0
# Grief (Emotion) (mentions: 81): -0.8
# Guantanamo Bay Naval Base (Cuba) (mentions: 87): -0.8
# Proud Boys (mentions: 20): 0.8
# Great Britain (mentions: 591): 0.8
# Hate Crimes (mentions: 70): -0.8
# Labour Party (Great Britain) (mentions: 128): 0.8
# Great Britain Withdrawal from EU (Brexit) (mentions: 20): 0.8
# Hate Speech (mentions: 27): -0.8
# Elizabeth II, Queen of Great Britain (mentions: 12): 0.8
# Conservative Party (Great Britain) (mentions: 104): 0.8
# Make America Great Again (MAGA) Inc (mentions: 13): 0.8
# Liberal Democrats (Great Britain) (mentions: 6): 0.8
# Great Plains (US) (mentions: 13): 0.8
# Great Lakes (mentions: 12): 0.8

# %%
from collections import Counter

# Collect all keywords from the DataFrame
all_keywords = []
for idx, row in more_info.iterrows():
    kws = extract_keyword_values(row['keywords'])
    all_keywords.extend(kws)

# Count the frequency of each keyword
keyword_counts = Counter(all_keywords)

# Print the top 20 most common keywords
print("Most Common Keywords:")
for keyword, count in keyword_counts.most_common(500):
    print(f"{keyword}: {count}")
# Out:
# Most Common Keywords:
# Trump, Donald J: 8078
# United States Politics and Government: 7584
# Presidential Election of 2024: 6515
# Biden, Joseph R Jr: 3250
# Politics and Government: 2898
# Israel-Gaza War (2023- ): 2494
# Elections: 2405
# Content Type: Personal Profile: 2221
# Harris, Kamala D: 2147
# Republican Party: 2138
# United States International Relations: 2115
# Democratic Party: 2055
# Books and Literature: 2051
# Israel: 1995
# United States: 1890
# New York City: 1837
# Movies: 1742
# Television: 1672
# International Relations: 1642
# Content Type: Service: 1616
# Defense and Military Forces: 1486
# Gaza Strip: 1407
# internal-paywall-exempt: 1327
# Social Media: 1296
# Crossword Puzzles: 1294
# Elections, House of Representatives: 1283
# Russian Invasion of Ukraine (2022): 1221
# Deaths (Obituaries): 1185
# Russia: 1144
# Computers and the Internet: 1115
# Global Warming: 1106
# Real Estate and Housing (Residential): 1105
# Palestinians: 1088
# Polls and Public Opinion: 1065
# Hamas: 1047
# China: 1029
# Decisions and Verdicts: 1023
# Law and Legislation: 1011
# Deaths (Fatalities): 979
# Art: 951
# Ukraine: 945
# Suits and Litigation (Civil): 939
# California: 914
# United States Economy: 893
# Primaries and Caucuses: 892
# Demonstrations, Protests and Riots: 889
# Regulation and Deregulation of Industry: 887
# internal-storyline-no: 858
# Cooking and Cookbooks: 824
# Musk, Elon: 822
# Appointments and Executive Changes: 815
# Pop and Rock Music: 793
# Black People: 788
# Blacks: 788
# Research: 768
# Fashion and Apparel: 754
# Immigration and Emigration: 752
# Women and Girls: 752
# Murders, Attempted Murders and Homicides: 751
# News and News Media: 734
# Terrorism: 723
# Colleges and Universities: 722
# Artificial Intelligence: 715
# Actors and Actresses: 709
# Supreme Court (US): 693
# Labor and Jobs: 684
# Illegal Immigration: 678
# Prices (Fares, Fees and Rates): 668
# Theater: 667
# Justice Department: 658
# Writing and Writers: 645
# House of Representatives: 644
# Netanyahu, Benjamin: 629
# Right-Wing Extremism and Alt-Right: 611
# Senate: 592
# Great Britain: 591
# International Trade and World Market: 586
# Vance, J D: 584
# Presidential Transition (US): 577
# Travel and Vacations: 576
# your-feed-science: 569
# Conservatism (US Politics): 569
# Discrimination: 557
# New York State Criminal Case Against Trump (71543-23): 556
# Iran: 550
# internal-truncator: 550
# audio-neutral-informative: 549
# Hezbollah: 548
# Museums: 536
# Rumors and Misinformation: 528
# Restaurants: 525
# Abortion: 524
# United States Defense and Military Forces: 490
# Race and Ethnicity: 482
# Greenhouse Gas Emissions: 481
# Adams, Eric L: 480
# Putin, Vladimir V: 472
# War and Armed Conflicts: 469
# Los Angeles (Calif): 468
# Ethics and Official Misconduct: 466
# Children and Childhood: 465
# Sex Crimes: 464
# Europe: 455
# Florida: 455
# Wildfires: 439
# Weather: 432
# Texas: 431
# Civilian Casualties: 427
# France: 424
# internal-open-access: 423
# New York State: 422
# Lebanon: 421
# Elections, Senate: 421
# AIRLINES AND AIRPLANES: 418
# Assassinations and Attempted Assassinations: 403
# Foreign Aid: 401
# Inflation (Economics): 391
# Debates (Political): 391
# Customs (Tariff): 385
# Presidential Election of 2020: 384
# Banking and Financial Institutions: 379
# Refugees and Displaced Persons: 377
# Vice Presidents and Vice Presidency (US): 377
# Kennedy, Robert F Jr: 376
# Wordle (Puzzle): 374
# Economic Conditions and Trends: 374
# Connections (Game): 373
# Fires and Firefighters: 371
# Spelling Bee (Game): 369
# vis-photo: 368
# Education (K-12): 368
# TikTok (ByteDance): 364
# Police: 363
# Protectionism (Trade): 361
# Comedy and Humor: 355
# Factories and Manufacturing: 355
# Coronavirus (2019-nCoV): 350
# Walz, Tim: 348
# Mexico: 347
# Documentary Films and Programs: 347
# Canada: 346
# Humanitarian Aid: 344
# Storming of the US Capitol (Jan, 2021): 342
# Manhattan (NYC): 340
# Video Recordings, Downloads and Streaming: 338
# Interest Rates: 336
# Kidnapping and Hostages: 327
# Medicine and Health: 327
# Federal Bureau of Investigation: 325
# Weddings and Engagements: 323
# Music: 323
# Iran-Israel Proxy Conflict: 316
# Presidents and Presidency (US): 316
# Hurricanes and Tropical Storms: 314
# Olympic Games (2024): 314
# North Carolina: 311
# Pennsylvania: 309
# Rap and Hip-Hop: 305
# Drug Abuse and Traffic: 304
# Executive Orders and Memorandums: 303
# Peace Process: 303
# internal-sub-only-nl: 303
# Mergers, Acquisitions and Divestitures: 302
# Dating and Relationships: 302
# Prisons and Prisoners: 300
# Games: 297
# Dancing: 297
# Arizona: 296
# Mental Health and Disorders: 296
# Floods: 295
# Germany: 294
# Courts and the Judiciary: 293
# Electric and Hybrid Vehicles: 293
# Southern California Wildfires (Jan 2025): 292
# Campaign Finance: 292
# Stocks and Bonds: 292
# Democracy (Theory and Philosophy): 292
# Automobiles: 291
# Georgia: 290
# Syria: 286
# internal-paywall-exempt-elections-app: 286
# Aviation Accidents, Safety and Disasters: 280
# Evacuations and Evacuees: 279
# Space and Astronomy: 276
# United Nations: 276
# Anti-Semitism: 275
# Frauds and Swindling: 275
# Federal-State Relations (US): 274
# Agriculture and Farming: 274
# Shopping and Retail: 273
# Culture (Arts): 272
# Democratic National Convention: 272
# Health Insurance and Managed Care: 271
# Classical Music: 270
# Jews and Judaism: 270
# European Union: 269
# Zelensky, Volodymyr: 269
# Presidential Elections (US): 267
# Homosexuality and Bisexuality: 266
# Oil (Petroleum) and Gasoline: 265
# Federal Reserve System: 265
# Voting and Voters: 264
# Theater (Broadway): 263
# Mobile Applications: 263
# Freedom of Speech and Expression: 262
# Organized Labor: 258
# New Jersey: 257
# Human Rights and Human Rights Violations: 257
# Vaccination and Immunization: 253
# Defense Department: 252
# Pro-Palestinian Campus Protests (2023- ): 252
# India: 251
# Paris (France): 248
# War Crimes, Genocide and Crimes Against Humanity: 247
# Transgender: 246
# Japan: 244
# Heat and Heat Waves: 244
# Food: 241
# Rain: 241
# Parenting: 241
# Espionage and Intelligence Services: 240
# Environment: 237
# Drugs (Pharmaceuticals): 235
# Workplace Hazards and Violations: 235
# Missiles and Missile Defense Systems: 235
# Layoffs and Job Reductions: 233
# Federal Budget (US): 232
# South Korea: 231
# Michigan: 228
# Personal Finances: 227
# Interior Design and Furnishings: 227
# Corruption (Institutional): 226
# X (Formerly Twitter): 225
# Age, Chronological: 224
# State Legislatures: 223
# Eric Adams Federal Corruption Case (24 CR 556): 218
# Conservation of Resources: 218
# Hochul, Kathleen C: 217
# Netflix Inc: 216
# Advertising and Marketing: 215
# Deportation: 214
# Income Inequality: 214
# Embargoes and Sanctions: 212
# Legislatures and Parliaments: 211
# Alternative and Renewable Energy: 210
# Disease Rates: 210
# Middle East: 210
# Assaults: 210
# OpenAI Labs: 208
# Photography: 208
# Youth: 208
# Women's Rights: 206
# Child Abuse and Neglect: 205
# Police Brutality, Misconduct and Shootings: 203
# Recipes: 203
# New York Times/Siena College Poll: 203
# Antitrust Laws and Competition Issues: 202
# North Atlantic Treaty Organization: 201
# AFRICA: 200
# New York Times: 199
# High Net Worth Individuals: 198
# Google Inc: 198
# Bribery and Kickbacks: 197
# Amnesties, Commutations and Pardons: 196
# Disasters and Emergencies: 194
# Compensation for Damages (Law): 194
# Voter Fraud (Election Fraud): 193
# Johnson, Mike (1972- ): 191
# Wages and Salaries: 190
# Diet and Nutrition: 189
# Government Efficiency Department (US): 188
# Wisconsin: 188
# Academy Awards (Oscars): 187
# Hospitals: 187
# Macron, Emmanuel (1977- ): 186
# Federal Aid (US): 185
# Christians and Christianity: 185
# Food and Drug Administration: 185
# Columbia University: 185
# Government Employees: 184
# internal-sub-only-audio: 184
# Newspapers: 182
# Political Prisoners: 181
# Chicago (Ill): 181
# Presidential Power (US): 180
# Urban Areas: 179
# Hispanic-Americans: 178
# States (US): 178
# Fans (Persons): 178
# Infrastructure (Public Works): 178
# Washington (DC): 177
# Love (Emotion): 177
# Doctors: 176
# Celebrities: 176
# Hurricane Helene (2024): 176
# Referendums: 175
# Real Estate (Commercial): 175
# Ohio: 175
# Teenagers and Adolescence: 174
# ARCHITECTURE: 173
# Drones (Pilotless Planes): 173
# Hotels and Travel Lodgings: 173
# Immunity from Prosecution: 173
# Philanthropy: 172
# Roman Catholic Church: 172
# Assad, Bashar al-: 172
# Renting and Leasing (Real Estate): 170
# Meta Platforms Inc: 170
# Asylum, Right of: 169
# London (England): 169
# England: 168
# Computer and Video Games: 168
# Tax Credits, Deductions and Exemptions: 168
# Minorities: 167
# Homeless Persons: 167
# Families and Family Life: 166
# Merchan, Juan M: 166
# Crime and Criminals: 165
# Historic Buildings and Sites: 164
# Conspiracy Theories: 164
# Obama, Barack: 164
# Republican National Convention: 164
# Centers for Disease Control and Prevention: 163
# Elections, State Legislature: 163
# Psychology and Psychologists: 161
# Local Government: 160
# Theater (Off Broadway): 159
# Holocaust and the Nazi Era: 159
# World War II (1939-45): 158
# Poverty: 157
# Men and Boys: 156
# Hegseth, Pete: 156
# Xi Jinping: 156
# Metropolitan Transportation Authority: 156
# Roads and Traffic: 156
# Subways: 155
# Nuclear Weapons: 154
# Federal Criminal Case Against Trump (Documents Case): 153
# Conflicts of Interest: 153
# Parties (Social): 153
# Accidents and Safety: 153
# Football: 151
# Gun Control: 151
# The Tonight Show (TV Program): 151
# Cohen, Michael D (1966- ): 150
# Opera: 149
# Collectors and Collections: 148
# Late Show with Stephen Colbert (TV Program): 148
# Tesla Motors Inc: 148
# Shutdowns (Institutional): 147
# Rafah (Gaza Strip): 147
# Podcasts: 147
# Exercise: 146
# West Bank: 146
# Blinken, Antony J: 145
# Muslims and Islam: 145
# Power Failures and Blackouts: 145
# Arms Trade: 144
# Italy: 144
# Brazil: 144
# Traffic Accidents and Safety: 144
# Animal Behavior: 143
# Political Advertising: 143
# Minnesota: 142
# Content Type: Quiz: 142
# Clifford, Stephanie (1979- ): 142
# Jimmy Kimmel Live (TV Program): 141
# Sculpture: 141
# vis-design: 140
# Fallon, Jimmy: 140
# Country Music: 139
# Homeland Security Department: 139
# Far East, South and Southeast Asia and Pacific Areas: 139
# Elections, Mayors: 138
# your-feed-healthcare: 138
# Maryland: 138
# Sexual Harassment: 137
# Health and Human Services Department: 137
# Science and Technology: 137
# Amazon.com Inc: 137
# Poetry and Poets: 137
# Congestion Pricing: 136
# Australia: 136
# San Francisco (Calif): 136
# Boeing Company: 136
# Environmental Protection Agency: 135
# Diversity Initiatives: 135
# Ships and Shipping: 135
# Endorsements: 134
# Gender: 133
# Baseball: 133
# internal-reader-callout: 132
# Hazardous and Toxic Substances: 132
# Inaugurations: 132
# Elections, Governors: 132
# Bragg, Alvin: 132
# Elderly: 131
# Newsom, Gavin: 131
# Jazz: 131
# Bars and Nightclubs: 131
# The Daily Show with Trevor Noah (TV Program): 131
# Smith, Jack (Attorney): 131
# Funerals and Memorials: 130
# Christmas: 130
# Endangered and Extinct Species: 129
# Air Pollution: 129
# Robberies and Thefts: 129
# Colbert, Stephen: 129
# Threats and Threatening Messages: 129
# Starmer, Keir: 128
# Book Trade and Publishing: 128
# Company Reports: 128
# Labour Party (Great Britain): 128
# Nebraska: 127
# Governors (US): 127
# Presidential Election of 2016: 127
# Brain: 126
# Soccer: 126
# Parks and Other Recreation Areas: 125
# Computer Chips: 125
# Egypt: 124
# Water: 123
# State Department: 123
# Electric Light and Power: 123
# Late Night with Seth Meyers (TV Program): 123
# Two Thousand Twenty Four: 123
# Media: 123
# Luxury Goods and Services: 123
# Brooklyn (NYC): 123
# Nevada: 123
# vis-video: 122
# Dogs: 122
# Start-ups: 122
# Classified Information and State Secrets: 122
# Legal Profession: 122
# Colorado: 122
# Instagram Inc: 121
# Republican National Committee: 121
# Maritime Accidents and Safety: 121
# Venezuela: 120
# Therapy and Rehabilitation: 120
# Home Repairs and Improvements: 120
# Police Department (NYC): 120
# Transit Systems: 120
# Ethics (Personal): 119
# Kimmel, Jimmy: 119
# Apple Inc: 119
# Pregnancy and Childbirth: 119
# Virtual Currency: 118
# Microsoft Corp: 118
# Basketball: 118
# Flowers and Plants: 118
# Rubio, Marco: 117
# Beijing Bytedance Technology Co Ltd: 117
# Firearms: 117
# Taiwan: 117
# Missouri: 117
# Anxiety and Stress: 116
# Virginia: 116
# Carter, Jimmy: 116
# Avian Influenza: 115
# Alabama: 114
# Affordable Housing: 114
# your-feed-fashion: 114
# Supreme Courts (State): 114
# Beirut (Lebanon): 114
# Attorneys General: 113
# Federal Criminal Case Against Trump (2020 Election Case): 113
# Royal Families: 113
# Privacy: 113
# Biden, Hunter: 113
# Treasury Department: 112
# Liberalism (US Politics): 112
# Small Business: 112
# Swift, Taylor: 111
# National Aeronautics and Space Administration: 111
# Bombs and Explosives: 111
# Pets: 111
# Strikes: 111
# Sustainable Living: 110
# Hiring and Promotion: 110
# Censorship: 110
# National Parks, Monuments and Seashores: 110
# Design: 110
# Cancer: 110
# Forests and Forestry: 110
# Washington (State): 110
# Supply Chain: 109
# Religion and Belief: 109
# Tests (Medical): 109
# Third-Party Politics (US): 109
# Restoration and Renovation: 108
# Constitution (US): 108
# Building (Construction): 108
# Rescues: 108
# Tennessee: 107
# Facebook Inc: 107
# Athletics and Sports: 107
# North Korea: 107
# Atlanta (Ga): 107
